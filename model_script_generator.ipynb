# %% [markdown]
# I should read the data study the data and fill this dictionary and that will leave me with only the tables to populate later.
#
# I will do a similar thing for:
# - forms.py
# - urls.py
# - views.py
# - admin.py
#
# - Tepmpaltes (lis, form, detail)
# - crisisdb_vars
#
# Don't forget the imports needed on the top of each file.

# %%
# choices

job_category_rate_of_return_choices = ["jobs requiring jinshi or juren examinations",
"jobs requiring shengyuan examination",
"jobs with less than shengyuan education"]

job_category_annual_wages_choices = ["jobs requiring jinshi or juren examinations",
"jobs requiring shengyuan examination",
"jobs with less than shengyuan education",
"jobs requiring no education"]

job_description_rate_of_return_choices = ["official service in central government or local government",
"secretarial assistants to high provincial officials",
"lecturer in large shuyuan",
"secretarial assistants to prefects and counties",
"scholar doctor in local community",
"service as gentry functions",
"teacher in local school",
"other services",
"skilled labour in silk-reel industry",
"teacher in local primary school"]

job_description_annual_wages_choices = ["official service in central government or local government",
"secretarial assistants to high provincial officials",
"lecturer in large shuyuan",
"secretarial assistants to prefects and counties",
"scholar doctor in local community",
"service as gentry functions",
"teacher in local school",
"other services",
"skilled labour in silk-reel industry",
"teacher in local primary school",
"general unskilled labour in big city",
"general unskilled labour in small town or village",]

# %%
# to_Form field converter
MYINT = ['IntegerField', 'NumberInput']
MYDEC = ['DecimalField', 'NumberInput']
MYTXT = ['CharField', 'TextInput']
# for these we need, the pandas dfs to smartly select the choices, put them in a tuple or list
MYTXT_CH = ['CharField', 'Select']


# the dictionary containing all the needed info for our code generators
vars_dic = {
    'population': {
        'dtype': MYINT,
        'varname': 'total_population',
        },
    'land_taxes_collected': {
        'dtype': MYINT,
        'varname': 'land_taxes_collected',
        'section': 'Fiscal Helath',
        },
    'land_yield': {
        'dtype': MYINT,
        'varname': 'land_yield',
        'section': 'Fiscal Helath',
        },
    'total_tax': {
        'dtype': MYINT,
        'varname': 'total_amount_of_taxes_collected',
        'section': 'Fiscal Helath',
        'vardesc': '',
        },
    'total_economic_output': {
        'dtype': MYINT,
        'varname': 'total_economic_output',
        'section': 'Fiscal Helath',
        },
    'total_revenue': {
        'dtype': MYINT,
        'varname': 'total_revenue',
        'vardesc': 'Total Revenue (in 1,000 taels)',
        },
    'diding_taxes': {
        'dtype': MYINT,
        'varname': 'total_revenue',
        'vardesc': 'Diding Taxes (in 1,000 taels)',
        'section': 'Fiscal Helath',

        },
    'salt_tax': {
        'dtype': MYINT,
        'varname': 'salt_tax',
        'vardesc': 'Salt Tax (in 1,000 taels)',
        'section': 'Fiscal Helath',

        },
    'tariff_and_transit': {
        'dtype': MYINT,
        'varname': 'tariff_and_transit',
        'vardesc': 'Tariff and transit (in 1,000 taels)',
        'section': 'Fiscal Helath',

        },
    'misc_incomes': {
        'dtype': MYINT,
        'varname': 'misc_incomes',
        'vardesc': 'Misc. incomes (in 1,000 taels)',
        'section': 'Fiscal Helath',

        },
    'total_expenditure': {
        'dtype': MYINT,
        'varname': 'total_expenditure',
        'vardesc': 'Total Expenditure (in 1,000 taels)',
        'section': 'Fiscal Helath',
        },
    'balance': {
        'dtype': MYINT,
        'varname': 'balance',
        'vardesc': 'Balance (in 1,000 taels)',
        'section': 'Fiscal Helath',
        },
    'lijin': {
        'dtype': MYINT,
        'varname': 'lijin',
        'vardesc': '(in 1,000 taels)',
        'section': 'Fiscal Helath',
        },
    'maritime_custom': {
        'dtype': MYINT,
        'varname': 'maritime_custom',
        'vardesc': '(in 1,000 taels)',
        'section': 'Fiscal Helath',
        },
    'other_incomes': {
        'dtype': MYINT,
        'varname': 'other_incomes',
        'vardesc': '(in 1,000 taels)',
        'section': 'Fiscal Helath',
        },
    'revenue_official': {
        'dtype': MYINT,
        'varname': 'revenue_official',
        'vardesc': '(in 1,000 taels)',
        'section': 'Fiscal Helath',
        },
    'revenue_real': {
        'dtype': MYINT,
        'varname': 'revenue_real',
        'vardesc': '(in 1,000 taels)',
        'section': 'Fiscal Helath',
        },
    'annual_wages': {
        'cols': 3,
        'col1': {
            'dtype': MYINT,
            'varname': 'annual_wages',
        },
        'col2': {
            'dtype': MYTXT_CH,
            'varname': 'job_category',
            'choices': job_category_annual_wages_choices,
        },
        'col3': {
            'dtype': MYTXT_CH,
            'varname': 'job_description',
            'choices': job_description_annual_wages_choices,
        },
        #'vardesc': '(in 1,000 taels)',
        'section': 'Institutional variables',
        'notes': 'in silver liang by level of education'
    },
    'rate_of_return': {
        'cols': 3,
        'col1': {
            'dtype': MYINT,
            'varname': 'annual_wages',
        },
        'col2': {
            'dtype': MYTXT_CH,
            'varname': 'job_category',
            'choices': job_category_rate_of_return_choices,
        },
        'col3': {
            'dtype': MYTXT_CH,
            'varname': 'job_description',
            'choices': job_description_rate_of_return_choices,
        },
        #'vardesc': '(in 1,000 taels)',
        'section': 'Wages',
        'notes': 'by level of education corrected for foregone wages and life expectancy, and the probability of successful examination'
    },
}

# %%
#%run '/home/majid/dev/seshat/helpers/input_choices.py'

# %%
#%run '/home/majid/dev/seshat/helpers/input_vars.py'

# %%
# %run '/home/majid/dev/seshat/helpers/input_utils.py'

# %%
choices_here = {
'job_category_annual_wages_choices': ("jobs requiring jinshi or juren examinations",
"jobs requiring shengyuan examination",
"jobs with less than shengyuan education",
"jobs requiring no education"),

'job_description_rate_of_return_choices': ("official service in central government or local government",
"secretarial assistants to high provincial officials",
"lecturer in large shuyuan",
"secretarial assistants to prefects and counties",
"scholar doctor in local community",
"service as gentry functions",
"teacher in local school",
"other services",
"skilled labour in silk-reel industry",
"teacher in local primary school"),

'job_description_annual_wages_choices': ("official service in central government or local government",
"secretarial assistants to high provincial officials",
"lecturer in large shuyuan",
"secretarial assistants to prefects and counties",
"scholar doctor in local community",
"service as gentry functions",
"teacher in local school",
"other services",
"skilled labour in silk-reel industry",
"teacher in local primary school",
"general unskilled labour in big city",
"general unskilled labour in small town or village",),


'sub_category_famine_event_choices': ["Famine", "Human-Eating"],

'magnitude_famine_event_choices': ["Uncertain", "Heavy", "Light", "Heavy- Multiple Times", 
                            "No Happening", "No description","Nonspecified",
                           ],

'duration_famine_event_choices': ["1 to 10 Days", # or 1 to 20 days???
"20 to 30 Days",
"30 to 60 Days",
"60 to 90 Days",
"Over 90 Days",
"No description",
"Uncertain",
],

'sub_category_disease_event_choices': ["Pestilence", "Peculiar Epidemics", "Pox", "Miasm", 
                                "Malaria", "Dysentery", "Uncertain Pestilence"
                               ],

'magnitude_disease_event_choices': ["Uncertain", "Heavy", "Light", "Heavy- Multiple Times", 
                            "No Happening", "No description","Nonspecified",
                            ],

'duration_disease_event_choices': ["1 to 10 Days", # or 1 to 20 days???
"20 to 30 Days",
"30 to 60 Days",
"60 to 90 Days",
"Over 90 Days",
"No description",
"Uncertain",
],
}

# %%
len(choices_here)
# Out:
# 9

# %%
# tuple generator
# my_tuples = []
# for k,v in choices_here.items():
#     my_tuples = []
#     for item in v:
#         my_tuple = (item, item) 
#         #print(my_tuple_str)#str(k) + " = " + "(" + 
#         my_tuples.append(my_tuple)
#     my_tuples_real = tuple(my_tuples)
#     print(k + " = " + str(my_tuples_real))
# Out:
# job_category_annual_wages_choices = (('jobs requiring jinshi or juren examinations', 'jobs requiring jinshi or juren examinations'), ('jobs requiring shengyuan examination', 'jobs requiring shengyuan examination'), ('jobs with less than shengyuan education', 'jobs with less than shengyuan education'), ('jobs requiring no education', 'jobs requiring no education'))
# ...

# %%
# %run '/home/majid/dev/seshat/helpers/input_utils.py'

# %%
str_models = model_generator(vars_dic)

with open("Output_for_models.py", "w") as text_file:
    for model in str_models:
        text_file.write(model)

# %% [markdown]
# # Serializers
# ---

# %%
# %run '/home/majid/dev/seshat/helpers/input_utils.py'

# %%
str_form_serials = serial_for_polity_serializer_generator(vars_dic)
str_serials = serial_generator(vars_dic)


with open("Output_for_serials.py", "w") as text_file:
    text_file.write(str_form_serials)
    text_file.write("\n")
    for serial in str_serials:
        text_file.write(serial)
# Out:
# Please insert that into the code a s well:
# ...

# %% [markdown]
# ---
#
# # Forms

# %%
# %run '/home/majid/dev/seshat/helpers/input_utils.py'

# %%
str_form_headers = form_header_generator(vars_dic)
str_forms = form_generator(vars_dic)


with open("Output_for_forms.py", "w") as text_file:
    text_file.write(str_form_headers)
    text_file.write("\n")
    for form in str_forms:
        text_file.write(form)

# %% [markdown]
# ---
# # URLS

# %%
# %run '/home/majid/dev/seshat/helpers/input_utils.py'

# %%
str_url_headers = url_header_generator(vars_dic)
str_urls = url_generator(vars_dic)


with open("Output_for_urls.py", "w") as text_file:
    text_file.write(str_url_headers)
    text_file.write("\n")
    for url in str_urls:
        text_file.write(url)

# %% [markdown]
# # VIEWS

# %%
# %run '/home/majid/dev/seshat/helpers/input_utils.py'

# %%
str_view_headers = view_header_generator(vars_dic)
str_view_headers_2 = view_header_generator_2(vars_dic)
# kaputt
# vars_dic_spec = generate_vars_dic(vars_dic)

str_views = view_generator(vars_dic)

#print(vars_dic_spec)
with open("Output_for_views.py", "w") as text_file:
    text_file.write(str_view_headers)
    text_file.write("\n")
    text_file.write(str_view_headers_2)
    text_file.write("\n")

    for view in str_views:
        text_file.write(view)

# %%
# generate vars_dic for qind_vars page
# needs fixing
print(generate_vars_dic(vars_dic))
# Out:
# {'Land_taxes_collected': {'model': 'Land_taxes_collected,', 'list': 'Land_taxes_collectedListView,', 'create': 'Land_taxes_collectedCreate,', 'section': 'Fiscal Helath', 'subsection': None}, 'Land_yield': {'model': 'Land_yield,', 'list': 'Land_yieldListView,', 'create': 'Land_yieldCreate,', 'section': 'Fiscal Helath', 'subsection': None}, 'Total_tax': {'model': 'Total_tax,', 'list': 'Total_taxListView,', 'create': 'Total_taxCreate,', 'section': 'Fiscal Helath', 'subsection': None}, 'Total_economic_output': {'model': 'Total_economic_output,', 'list': 'Total_economic_outputListView,', 'create': 'Total_economic_outputCreate,', 'section': 'Fiscal Helath', 'subsection': None}, 'Total_revenue': {'model': 'Total_revenue,', 'list': 'Total_revenueListView,', 'create': 'Total_revenueCreate,', 'section': None, 'subsection': None}, 'Diding_taxes': {'model': 'Diding_taxes,', 'list': 'Diding_taxesListView,', 'create': 'Diding_taxesCreate,', 'section': 'Fiscal Helath', 'subsection': None}, 'Salt_ta
# ...

# %% [markdown]
# ---
# # admin

# %%
str_admin_headers = admin_header_generator(vars_dic)

with open("Output_for_admin.py", "w") as text_file:
    text_file.write(str_admin_headers)
    text_file.write("\n\n")
    for k in vars_dic.keys():
        admin_register_line = f"admin.site.register({k.capitalize()})"
        text_file.write(admin_register_line)
        text_file.write("\n")

# %%
# for admin.py template:
# maybe better if I add the inlinesand others first
# But I can go on like this for now

#from .models import Population

#admin.site.register(Population)

# %%
def templates_folder_make(k):
    foldername = k

    # Create the root folder (once)
    rootfolder = "all_seshat_html_templates"
    if not os.path.exists(rootfolder):
        os.mkdir(rootfolder)

    inner_folder = rootfolder + "/" + foldername
    # Create the insider folders (if not already done)
    if not os.path.exists(rootfolder + "/" + foldername ):
        os.mkdir(inner_folder)
        
    full_name_list = inner_folder + "/" + k +"_list.html"
    full_name_detail = inner_folder  + "/" + k +"_detail.html"
    full_name_form = inner_folder + "/" + k +"_form.html"
    full_name_update = inner_folder + "/" + k +"_update.html"
    return (full_name_list, full_name_detail, full_name_form, full_name_update)

# %%
b, c, d, f = templates_folder_make('majid')

# %%
b
# Out:
# 'all_seshat_html_templates/majid/majid_list.html'

# %% [markdown]
# ---
# # Templates
#
# ## All at once
#
# ### Assumptions:
# - Each model has only one extra_field

# %%
#import os

# %%
# %run '/home/majid/dev/seshat/helpers/input_utils.py'

# %%
# This takes care of all the templates for (_list, _detail, _form) in vars_dic:
# Awesome
create_all_templates(vars_dic)
# Out:
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# {% block addmore %}
# <a href="{% url 'population-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &#128934; &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
# <a href="{% url 'populations' %}" class="btn btn-outline-primary ms-auto my-4 float-end">&#8983; See All Such Facts
# </a>
# {% endblock addmore %}
#
# {% block myheadings %}
# <th class = "fw-normal" style="text-align: center;" scope="col">Total Population</th>
# {% endblock myheadings %}
#
# {% block extracols %}
# <td class="NORMAL" style="text-align: center;">{{ object.total_population|intcomma }}</td>
# {% endblock extracols %}
#
# {% extends "core/form_base.html" %}
# {% load crispy_forms_tags %}
# {% load humanize %}
#
# {% block extra_vars %}
#     <div class="col-md-4 mb-2">
#         {{ form.total_population|as_crispy_field }}
#     </div>
# {% endblock extra_vars %}
#
# {% block extra_vars2 %}
#
# ...

# %%
varname = "make_me_crazy_here_and_now_from_all_the_madness"
spaced_value_list = varname.split("_")
new_spaced_value_list = []
for item in spaced_value_list:
    if len(item) >= 3 and item.lower() not in ["for", "and", "from", "the"]:
        new_spaced_value_list.append(item.capitalize())
    else:
        new_spaced_value_list.append(item)
print(new_spaced_value_list)
# Out:
# ['Make', 'me', 'Crazy', 'Here', 'and', 'Now', 'from', 'All', 'the', 'Madness']

# %%
print(template_detail_generator(vars_dic))
# Out:
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# <a href="{% url 'land_taxes_collected-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
#
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# <a href="{% url 'land_yield-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
#
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# <a href="{% url 'total_tax-create' %}" class="btn btn-outline-success mx-3 my-4 float-end"> &nbsp; Add Another Fact &nbsp; <i class="fa fa-plus"></i>
# </a>
#
#
# {% extends "core/detail_base.html" %}
# {% load static %}
# {% load humanize %}
#
# ...

# %% [markdown]
# <hr>
#
# # END OF FILE GENERATIONS

# %% [markdown]
# # Read Data and Populate database

# %%
import pandas as pd

# %%
# We can have the list of all files and sheets
# and give them as input to the following function
my_files_details = {
    "tax_burden.xlsx": ['Sheet1', 'Sheet2', 'Sheet3', 'Sheet4'],
    "annual_wages_in_silver_liang.xlsx": ['Sheet1_MCMA', 'Sheet2_MCMA'],
    "Chinas_GDP.xlsx": ['Sheet1', 'Sheet2', 'Sheet3', 'Sheet4', 'Sheet5'],
    "Famine_Disease_from_Qing_datasets_2_sheets.xlsx": ["Qing_Wages", "Qing_Famine_MCMA",
                                                       "PROBLEMATIC_Qing_Conflicts_COW",
                                                       "Qing_Disease_MCMA"],
    "Jinshi_examination.xlsx": ['Sheet1_MCMA', 'Sheet2_MCMA', 'Sheet3_MCMA'],
    "Taiping_rebellion_leaders.xlsx": ['Sheet1_MCMA',],
    "wages_of_workers.xlsx": ['Sheet1_MCMA',],
}

# %%
# %run '/home/majid/dev/seshat/helpers/input_vars.py'

# %%
job_category_annual_wages_choices
# Out:
# ['jobs requiring jinshi or juren examinations',
#  'jobs requiring shengyuan examination',
#  'jobs with less than shengyuan education',
#  'jobs requiring no education']

# %%
# %run '/home/majid/dev/seshat/helpers/input_utils.py'

# %%
#my_df = read_and_save_all_excel_sheets("tax_burden.xlsx", ['Sheet1', 'Sheet2', 'Sheet3', 'Sheet4'], {})

# %%
my_good_dfs = read_and_save_all_excel_sheets_at_once(my_files_details)

# %%
len(my_good_dfs)
# Out:
# 7

# %%
my_good_dfs.keys()
# Out:
# dict_keys(['tax_burden.xlsx', 'annual_wages_in_silver_liang.xlsx', 'Chinas_GDP.xlsx', 'Famine_Disease_from_Qing_datasets_2_sheets.xlsx', 'Jinshi_examination.xlsx', 'Taiping_rebellion_leaders.xlsx', 'wages_of_workers.xlsx'])

# %%
#len(my_good_dfs['annual_wages_in_silver_liang.xlsx'])

# %%
my_good_dfs['tax_burden.xlsx']['Sheet1']
# Out:
#    year_from  land_taxes_collected  land_yield
# 0       1652                 49795      315991
# 1       1685                 38809      415359
# 2       1724                 33550      890648
# 3       1766                 57360     1783965
# 4       1784                 54348     1646449
# 5       1820                 63478     2313710

# %%
# we have all the details in a my_dfs list
# To access one full df: my_dfs[i]     -----> This will be a dataframe with all the good data

# %%
from datetime import date
for my_key, my_v in my_files_details.items():
    # build df
    for my_sheet in my_v:
        df = my_good_dfs[my_key][my_sheet]
        #df = df_old.where(pd.notnull(df), None)
        sheet = str(my_key) + str(my_sheet)
        list_of_columns = df.columns.values.tolist()
        my_str_list = []
        bad_cols = ["year_from", "year_to", "PolID", "Source", "section", "Section", 'note',
                    'source', 'sources', 'description', 'citation', 'data_source']
        # will keep the list of all good columns
        selected_list = []
        #df["year_from"] = df["year_from"].astype("int64")
        for item in list_of_columns:
            if item not in bad_cols:
                selected_list.append(item)
        #  we go through each row of the spread sheet to make one (or several) model instances
        # Mullti Column Models Available in this Sheet
        if "PROBLEMATIC" in str(my_sheet):
            continue
        if 'MCMA' in str(my_sheet):
            MCMA_list_of_vars = ', '.join(selected_list)
            main_column = 'MYMAINCOLUMN'
            for mycol in list_of_columns:
                if mycol in vars_dic.keys():
                    main_column = mycol
            for row in range(df.shape[0]):
                polity_id = 3
                if df['year_from'][row].astype('int64') >= 1795:
                    polity_id = 4
                spaced_name = underscore_to_space(main_column)
                year_from_df = df['year_from'][row].astype('int64')
                year_to_df = df['year_from'][row].astype('int64')
                if 'year_to' in list_of_columns:
                    year_to_df = df['year_to'][row].astype('int64')
                MCMA_list_of_values = []
                MCMA_list_of_types = []
                if "note" in list_of_columns:
                    mynote = "\'" + str(df["note"][row]) + "\'"
                else:
                    mynote = "NULL"
                
                for column in selected_list:
                    #print('here we go', df[column].dtypes)
                    #MCMA_list_of_types.append(str(df[column].dtypes))
                    if str(df[column].dtypes) == 'object':
                        to_be_appended = "\'" + str(df[column][row]) + "\'"
                        MCMA_list_of_values.append(to_be_appended)
                    else:
                        MCMA_list_of_values.append(str(df[column][row]))
                        
                MCMA_list_of_values_str = ', '.join(MCMA_list_of_values)
                #MCMA_list_of_types_str = ', '.join(MCMA_list_of_types)
                sql_line = f"INSERT INTO crisisdb_{main_column} (polity_id, year_from, year_to, {MCMA_list_of_vars}, finalized, tag, name, note, created_date) VALUES ({polity_id}, {year_from_df}, {year_to_df}, {MCMA_list_of_values_str}, True, 'TRS', '{spaced_name}', {mynote},'{date.today()}');"
                # replace "nan" with NULL
                better_sql_line = sql_line.replace("\'nan\'", "NULL")
                best_sql_line = better_sql_line.replace(" nan,", " NULL,")
                
                my_str_list.append(best_sql_line)
                #print(MCMA_list_of_vars)
            #print(list_of_columns)
            #print(selected_list)
            
        # Each column represents a Model
        else:   
            for row in range(df.shape[0]):
                # we go through all the columns for the cases when each column is a separate model
                for column in selected_list:
                    if column == "note":
                        continue
                    else:
                        polity_id = 3
                        if df['year_from'][row].astype('int64') >= 1795:
                            polity_id = 4
                        spaced_name = underscore_to_space(column)

                        if str(df[column].dtypes) == 'object':
                            myvarsql_value = "\'" + str(df[column][row]) + "\'"
                        elif str(df[column].dtypes) == 'int64':
                            myvarsql_value = str(df[column][row].astype('int64'))
                        elif str(df[column].dtypes) == 'float64':
                            myvarsql_value = str(df[column][row].astype('float64'))
                            #myvarsql_value = str(df[column][row].astype('float64'))
                        else:
                            myvarsql_value = str(df[column][row])
                        
                        if "note" in list_of_columns:
                            mynote = "\'" + str(df["note"][row]) + "\'"
                        else:
                            mynote = "NULL"
                        myvarsql = vars_dic[column]["varname"]
                        year_from_df = df["year_from"][row].astype('int64')
                        year_to_df = df['year_from'][row].astype('int64')
                        if 'year_to' in list_of_columns:
                            year_to_df = df['year_to'][row].astype('int64')
                        #df[column].where(df[column].notnull(), None)
                        if pd.isna(df[column][row]):
                            sql_line = f"INSERT INTO crisisdb_{column} (polity_id, year_from, year_to, note, {myvarsql}, finalized, tag, name, created_date) VALUES ({polity_id}, {year_from_df}, {year_to_df}, {mynote}, NULL, True, 'TRS', '{spaced_name}', '{date.today()}');"
                        else:
                            sql_line = f"INSERT INTO crisisdb_{column} (polity_id, year_from, year_to, note, {myvarsql}, finalized, tag, name, created_date) VALUES ({polity_id}, {year_from_df}, {year_to_df}, {mynote}, {myvarsql_value}, True, 'TRS', '{spaced_name}', '{date.today()}');"
                        # replace "nan" with NULL
                        better_sql_line = sql_line.replace("\'nan\'", "NULL")
                        best_sql_line = better_sql_line.replace(" nan,", " NULL,")
                
                        my_str_list.append(best_sql_line)
        sql_file_name = sheet+".sql"
        with open(sql_file_name , "w") as sql_file:
            for l in my_str_list:
                sql_file.write(l)
                sql_file.write("\n")
        #print(my_str_dic)

# %%
# Backup from 10 april

from datetime import date

for sheet, df in my_good_dfs.items():
    list_of_columns = df.columns.values.tolist()
    my_str_list = []
    bad_cols = ["year_from", "year_to", "PolID", 'source', 'description', 'citation']
    selected_list = []
    common_list = []
    #df["year_from"] = df["year_from"].astype("int64")
    for item in list_of_columns:
        if item not in bad_cols:
            selected_list.append(item)
            
    for row in range(df.shape[0]):      
        for column in selected_list:
            polity_id = 3
            if df['year_from'][row].astype('int64') >= 1795:
                polity_id = 4
            spaced_name = underscore_to_space(column)  
            myvarsql = vars_dic[column]["varname"]
            #df[column].where(df[column].notnull(), None)
            if pd.isna(df[column][row]):
                sql_line = f"INSERT INTO crisisdb_{column} (polity_id, year_from, {myvarsql}, finalized, tag, name, created_date) VALUES ({polity_id}, {df['year_from'][row].astype('int64')}, NULL, True, 'TRS', '{spaced_name}', '{date.today()}');"
            else:
                sql_line = f"INSERT INTO crisisdb_{column} (polity_id, year_from, {myvarsql}, finalized, tag, name, created_date) VALUES ({polity_id}, {df['year_from'][row].astype('int64')}, {df[column][row].astype('int64')}, True, 'TRS', '{spaced_name}', '{date.today()}');"

            my_str_list.append(sql_line)
            #print()
    
    sql_file_name = sheet+".sql"
    with open(sql_file_name , "w") as sql_file:
        for l in my_str_list:
            sql_file.write(l)
            sql_file.write("\n")
    #print(my_str_dic)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-20ca0484b8a8> in <module>
#       4
#       5 for sheet, df in my_good_dfs.items():
# ----> 6     list_of_columns = df.columns.values.tolist()
#       7     my_str_list = []
#       8     bad_cols = ["year_from", "year_to", "PolID", 'source', 'description', 'citation']
#
# AttributeError: 'dict' object has no attribute 'columns'

# %%
from datetime import date
my_str_list_all = []

# this block goes through a set of key, value pairs where:
# key: name of the file+sheet containing data
# value: df containing the data
for sheet, df in my_good_dfs.items():
    list_of_columns = df.columns.values.tolist()
    my_str_list = []
    bad_cols = ["year_from", "year_to", "PolID",]
    selected_list = []
    common_list = []
    #df["year_from"] = df["year_from"].astype("int64")
    for item in list_of_columns:
        if item not in bad_cols:
            selected_list.append(item)
            
    for row in range(df.shape[0]):      
        for column in selected_list:
            polity_id = 1
            if df['year_from'][row].astype('int64') >= 1795:
                polity_id = 2
            spaced_name = underscore_to_space(column)  
            myvarsql = vars_dic[column]["varname"]
            #df[column].where(df[column].notnull(), None)
            if pd.isna(df[column][row]):
                sql_line = f"INSERT INTO crisisdb_{column} (polity_id, year_from, {myvarsql}, finalized, tag, name, created_date) VALUES ({polity_id}, {df['year_from'][row].astype('int64')}, NULL, True, 'TRS', '{spaced_name}', '{date.today()}');"
            else:
                sql_line = f"INSERT INTO crisisdb_{column} (polity_id, year_from, {myvarsql}, finalized, tag, name, created_date) VALUES ({polity_id}, {df['year_from'][row].astype('int64')}, {df[column][row].astype('int64')}, True, 'TRS', '{spaced_name}', '{date.today()}');"

            my_str_list.append(sql_line)
            my_str_list_all.append(sql_line)
            #print()
    

    #print(my_str_dic)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-280eb327baef> in <module>
#       6 # value: df containing the data
#       7 for sheet, df in my_good_dfs.items():
# ----> 8     list_of_columns = df.columns.values.tolist()
#       9     my_str_list = []
#      10     bad_cols = ["year_from", "year_to", "PolID",]
#
# AttributeError: 'dict' object has no attribute 'columns'

# %%
# Extra
sql_file_name = "tariff_special"+".sql"
with open(sql_file_name , "w") as sql_file:
    for l in my_str_list_all:
        if "INSERT INTO crisisdb_tariff_and" in l:
            sql_file.write(l)
            sql_file.write("\n")

# %%
from datetime import date
a = date.today()

# %%
print(a)
# Out:
# 2022-03-08
